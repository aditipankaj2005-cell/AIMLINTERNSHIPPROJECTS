# %% [markdown]
# Note: Run this notebook in Google Colab

# %% [markdown]
# This notebook is essentially an end-to-end NLP pipeline using Hugging Face Transformers on Dhurandhar 2 movie reviews.
#
# Key NLP Tasks Demonstrated
# * Sentiment Analysis → Positive/Negative classification
# * Machine Translation → English → Spanish
# * Question Answering → Extract information from reviews
# * Text Summarization → Generate concise review summaries
# * Model Evaluation → Accuracy, F1 Score, BLEU Score

# %% [markdown]
# # Insert necessary Libraries

# %%
# !pip install transformers evaluate
# !pip install -U transformers sentencepiece sacremoses
# !pip install evaluate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.13.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.12/dist-packages (0.4.6)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.7.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.29.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.14.1)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.6.17)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.13.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.12/dist-packages (0.1.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from sacremoses) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from sacremoses) (1.5.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.12/dist-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.7.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.29.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.14.1)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.6.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.14.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.7.0->evaluate) (0.1.2)

# %% [markdown]
# # Check the version of Trnasformation

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.13.0

# %% [markdown]
# # Ingest dataset for sample reviews, also, segregate Review and Label columns

# %%
import pandas as pd
import torch

# Load the car reviews dataset
file_path = "/content/sample_data/netflix movie KGF 2.csv"
df = pd.read_csv(file_path, delimiter=";")

# Put the car reviews and their associated sentiment labels in two lists
reviews = df['Review'].tolist()
real_labels = df['Class'].tolist()

# %% [markdown]
# # create a pipeline for the task sentiment-analysis using LLM Model

# %%
# Instruction 1: sentiment classification


# Load a sentiment analysis LLM into a pipeline
from transformers import pipeline
classifier = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')

# The Pipeline is a simple but powerful inference API that is readily
# available for a variety of machine learning tasks with any model from the Hugging Face Hub.

# This pipeline performs text classification on a given input and determines if its a
# positive or negative sentiment. You can pass
# multiple texts to the same pipeline, which will be processed and passed through the model together as a batch.

# distilbert-base-uncased-finetuned-sst-2-english: This model is a fine-tune checkpoint of DistilBERT-base-uncased,
# fine-tuned on SST-2.

# Developed by: Hugging Face
# Model Type: Text Classification

# This model can be used for topic classification. You can use the raw model for either masked language
# modeling or next sentence prediction, but it's mostly intended to be fine-tuned on a downstream task.
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %% [markdown]
# # Check sample review

# %%
print(reviews)
# Out:
# ["Aditya Dhar delivers a gripping and ambitious crime-thriller with Dhurandhar: The Revenge. From the very first scene, the film pulls you into a dangerous world of espionage, loyalty, betrayal, and survival. The story follows Jaskirat Singh Rangi as he fully embraces his identity as Hamza Ali Mazari and rises through Karachi's criminal underworld, creating a tense and emotionally charged journey. Ranveer Singh is absolutely phenomenal in the lead role. His transformation is intense, convincing, and filled with emotional depth. He brings both vulnerability and ruthless determination to the character, making Hamza Ali Mazari one of the most memorable protagonists in recent Indian cinema. Industry veterans have even praised his performance as award-worthy. The supporting cast is equally impressive. Akshaye Khanna delivers a powerful and nuanced performance, while Sanjay Dutt commands every scene with his presence. The ensemble cast elevates the narrative and keeps the tension high throughout the film. What truly stands out is Aditya Dhar's direction. The world-building is rich, the action sequences are impactful, and the attention to detail creates an immersive experience. The film balances large-scale action with personal drama, ensuring that the emotional stakes remain just as important as the spectacle. Many viewers have praised the realism of the setting and the film's ability to keep audiences engaged from beginning to end. The cinematography, background score, and production values are top-notch, giving the film an international feel while staying rooted in its story. Despite its ambitious scope, the narrative remains focused on the human cost of power, revenge, and survival. Overall, Dhurandhar: The Revenge is a thrilling cinematic experience that combines strong performances, stylish direction, and an engaging storyline. A must-watch for fans of crime dramas, espionage thrillers, and powerful character-driven cinema..", "After the success of the first film, I expected Dhurandhar 2 to raise the stakes and deliver a gripping continuation of Jaskirat Singh Rangi's journey into Karachi's criminal underworld. Unfortunately, the film ends up being a bloated and uneven experience that struggles to justify its lengthy runtime. The biggest issue is the screenplay. Despite an interesting premise involving undercover operations, gang rivalries, loyalty, and betrayal, the narrative moves at a painfully slow pace. Large portions of the film feel repetitive, with the same themes and conflicts being revisited without adding anything meaningful to the story. What should have been a tense crime-thriller often turns into a drawn-out exercise in patience. Ranveer Singh puts in effort as Hamza Ali Mazari, but the character is written almost invincible, leaving little room for suspense or emotional investment. The film repeatedly tells us how dangerous and intelligent he is instead of showing genuine challenges that test him. As a result, many key moments lack impact. Some viewers have similarly noted that the protagonist faces very few meaningful setbacks, making the story predictable. The supporting cast, including Akshaye Khanna and Sanjay Dutt, delivers respectable performances, but most characters are underutilized. Several talented actors appear capable of adding depth to the story, yet they are reduced to serving the plot rather than becoming memorable individuals. According to the film's cast listings, the movie boasts a strong ensemble, but the script rarely gives them enough material to shine. The action sequences are stylish and technically competent, but the excessive focus on violence and spectacle often comes at the expense of storytelling. Emotional scenes feel rushed, while action scenes are stretched far beyond what is necessary. The film seems more interested in looking intense than creating genuine tension. Another major problem is the lack of surprises. Twists are easy to predict, character motivations become obvious earl ...

# %% [markdown]
# # Print the respective label

# %%
print(real_labels)
# Out:
# ['POSITIVE', 'NEGATIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE']

# %% [markdown]
# # Custom review provided by User

# %%
reviews_example="The movie was fantastic!"
predicted_labels1 = classifier(reviews_example)
print(predicted_labels1 )
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998776912689209}]

# %% [markdown]
# # Load accuracy and F1 score metrics for given dataset

# %%
# Perform inference on the movie reviews and display prediction results
predicted_labels = classifier(reviews)
for review, prediction, label in zip(reviews, predicted_labels, real_labels):
    print(f"Review: {review}\nActual Sentiment: {label}\nPredicted Sentiment: {prediction['label']} (Confidence: {prediction['score']:.4f})\n")

# Load accuracy and F1 score metrics
import evaluate
# Evaluate is a library that makes evaluating
# and comparing models and reporting their performance easier and more standardized.
accuracy = evaluate.load("accuracy")
f1 = evaluate.load("f1")
# Out:
# Review: Aditya Dhar delivers a gripping and ambitious crime-thriller with Dhurandhar: The Revenge. From the very first scene, the film pulls you into a dangerous world of espionage, loyalty, betrayal, and survival. The story follows Jaskirat Singh Rangi as he fully embraces his identity as Hamza Ali Mazari and rises through Karachi's criminal underworld, creating a tense and emotionally charged journey. Ranveer Singh is absolutely phenomenal in the lead role. His transformation is intense, convincing, and filled with emotional depth. He brings both vulnerability and ruthless determination to the character, making Hamza Ali Mazari one of the most memorable protagonists in recent Indian cinema. Industry veterans have even praised his performance as award-worthy. The supporting cast is equally impressive. Akshaye Khanna delivers a powerful and nuanced performance, while Sanjay Dutt commands every scene with his presence. The ensemble cast elevates the narrative and keeps the tension high throughout the film. What truly stands out is Aditya Dhar's direction. The world-building is rich, the action sequences are impactful, and the attention to detail creates an immersive experience. The film balances large-scale action with personal drama, ensuring that the emotional stakes remain just as important as the spectacle. Many viewers have praised the realism of the setting and the film's ability to keep audiences engaged from beginning to end. The cinematography, background score, and production values are top-notch, giving the film an international feel while staying rooted in its story. Despite its ambitious scope, the narrative remains focused on the human cost of power, revenge, and survival. Overall, Dhurandhar: The Revenge is a thrilling cinematic experience that combines strong performances, stylish direction, and an engaging storyline. A must-watch for fans of crime dramas, espionage thrillers, and powerful character-driven cinema..
# Actual Sentiment: POSITIVE
# Predicted Sentiment: POSITIVE (Confidence: 0.9998)
#
# Review: After the success of the first film, I expected Dhurandhar 2 to raise the stakes and deliver a gripping continuation of Jaskirat Singh Rangi's journey into Karachi's criminal underworld. Unfortunately, the film ends up being a bloated and uneven experience that struggles to justify its lengthy runtime. The biggest issue is the screenplay. Despite an interesting premise involving undercover operations, gang rivalries, loyalty, and betrayal, the narrative moves at a painfully slow pace. Large portions of the film feel repetitive, with the same themes and conflicts being revisited without adding anything meaningful to the story. What should have been a tense crime-thriller often turns into a drawn-out exercise in patience. Ranveer Singh puts in effort as Hamza Ali Mazari, but the character is written almost invincible, leaving little room for suspense or emotional investment. The film repeatedly tells us how dangerous and intelligent he is instead of showing genuine challenges that test him. As a result, many key moments lack impact. Some viewers have similarly noted that the protagonist faces very few meaningful setbacks, making the story predictable. The supporting cast,
# Actual Sentiment: NEGATIVE
# Predicted Sentiment: NEGATIVE (Confidence: 0.9958)
#
# Review: Dhurandhar is a bold, intense, and thoroughly engaging crime thriller that keeps you invested from start to finish. Director Aditya Dhar crafts a dark and immersive world where loyalty, betrayal, ambition, and survival collide in spectacular fashion. The story of Jaskirat Singh Rangi's transformation into Hamza Ali Mazari and his rise through Karachi's ruthless criminal underworld is both compelling and emotionally charged. The film's premise revolves around an undercover operative navigating Pakistan's criminal networks while pursuing a dangerous mission. Ranveer Singh delivers one of the strongest performances of his career. His transformation is remarkable, bringing both vulnerability and ferocity to the character. Akshaye Khanna is exceptional as always, commanding every scene with his presence, while Sanjay Dutt adds tremendous gravitas and intensity. The supporting cast also contributes significantly to the film's immersive atmosphere. The cinematography, background score, and production design create a realistic and gritty environment that perfectly complements the story. The action sequences are impactful, but what truly stands out is the emotional depth behind the characters and their choices. Aditya Dhar deserves credit for delivering a large-scale thriller that balances action, suspense, and character development. The film's ambitious storytelling and powerful performances make it a memorable cinematic experience. It's easy to see why many viewers are praising the film, and industry figures have even described it as a game-changing project for Indian cinema. If you're a fan of crime dramas, espionage thrillers, and character-driven storytelling, Dhurandhar is absolutely worth watching. A gripping, high-stakes journey that leaves a lasting impression."
# Actual Sentiment: POSITIVE
# Predicted Sentiment: POSITIVE (Confidence: 0.9999)
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]

# %% [markdown]
# # Map categorical sentiment labels into integer labels

# %%
references = [1 if label == "POSITIVE" else 0 for label in real_labels]
predictions = [1 if label['label'] == "POSITIVE" else 0 for label in predicted_labels]

# Calculate accuracy and F1 score
accuracy_result_dict = accuracy.compute(references=references, predictions=predictions)
accuracy_result = accuracy_result_dict['accuracy']
f1_result_dict = f1.compute(references=references, predictions=predictions)
f1_result = f1_result_dict['f1']
print(f"Accuracy: {accuracy_result}")
print(f"F1 result: {f1_result}")
# Out:
# Accuracy: 1.0
# F1 result: 1.0

# %% [markdown]
# *   Sample Review: KGF 2 is an amazing movie with powerful action and excellent performance.
# *   Sentiment Analysis: POSITIVE

# %%
# Sentiment Analysis for a Sample Movie Review
# Provide your own sample review below
sample_review = "KGF 2 is an amazing movie with powerful action and excellent performance."

# Generate sentiment prediction using the previously loaded classifier
sentiment_result = classifier(sample_review)

# Extract sentiment label: POSITIVE or NEGATIVE
sentiment = sentiment_result[0]['label']

print("Sample Review:", sample_review)
print("Sentiment Analysis:", sentiment)
# Out:
# Sample Review: KGF 2 is an amazing movie with powerful action and excellent performance.
# Sentiment Analysis: POSITIVE

# %% [markdown]
# # Project ends here

# %% [markdown]
# ############################################################################################
